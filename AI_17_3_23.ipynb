# %% [markdown]
# <a href="https://colab.research.google.com/github/TruongTrungQuan20146404/Truong_Trung_Quan_20146404/blob/main/AI_17_3_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
url = 'mtcars.csv'
data = pd.read_csv(url)
data.head()
# Out:
#           Unnamed: 0   mpg   disp   hp     wt
# 0          Mazda RX4  21.0  160.0  110  2.620
# 1      Mazda RX4 Wag  21.0  160.0  110  2.875
# 2         Datsun 710  22.8  108.0   93  2.320
# 3     Hornet 4 Drive  21.4  258.0  110  3.215
# 4  Hornet Sportabout  18.7  360.0  175  3.440

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation = data.corr()
print(correlation)
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000

# %%
sns.pairplot(data)

# %%
sns.heatmap(correlation,annot = True)
# Out:
# <Axes: >

# %%
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9), color='black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='wt', ylabel='mpg'>

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()
model.fit(X = pd.DataFrame(data['wt']),y=data['mpg'])
print('Gia tri Intercept la:',model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
# Out:
# Gia tri Intercept la: 37.28512616734204
# Gia tri Coeffient la: [-5.34447157]

# %%
model.score(X = pd.DataFrame(data['wt']),y=data['mpg'])
# Out:
# 0.7528327936582646

# %%
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9), color='black')
y_pred=model.predict(X = pd.DataFrame(data['wt']))
plt.plot(data['wt'],y_pred, color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2]).T
model.fit(X,y=data['mpg'])
print('He so Intercept la:', model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print('Do chinh xac cua mo hinh:', model.score(X,y=data['mpg']))
# Out:
# He so Intercept la: 49.93081094945181
# Gia tri Coeffient la: [-13.38033708   1.17108689]
# Do chinh xac cua mo hinh: 0.8190613581384094

# %%
import numpy as np
range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter',x='wt',y='mpg',figsize=(9,9),color='black', xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3]).T
model.fit(X,y=data['mpg'])
print('He so Intercept la:', model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print('Do chinh xac cua mo hinh:', model.score(X,y=data['mpg']))
# Out:
# He so Intercept la: 48.40369622795221
# Gia tri Coeffient la: [-11.82597602   0.68937919   0.04593618]
# Do chinh xac cua mo hinh: 0.8191284628478992

# %%
import numpy as np


range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range,range**2,range**3]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter',x='wt',y='mpg',figsize=(9,9),color='black', xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5]).T
model.fit(X,y=data['mpg'])
print('He so Intercept la:', model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print('Do chinh xac cua mo hinh:', model.score(X,y=data['mpg']))
# Out:
# He so Intercept la: -87.71816314301019
# Gia tri Coeffient la: [ 218.88967608 -147.77842682   45.60934841   -6.70138798    0.37968337]
# Do chinh xac cua mo hinh: 0.8251088272653132

# %%
import numpy as np


range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range,range**2,range**3,range**4,range**5]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scat
# 49       0.00  0.000000e+00  0.000000e+00 mpg

# %%
model = linear_model.LinearRegression()
model.fit(X=data.loc[:,['wt','hp','disp']],y=data['mpg'])
y='mpg'
print('He so Intercept la:', model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print('Do chinh xac cua mo hinh:', X,y)
# Out:
# He so Intercept la: 37.10550526903184
# Gia tri Coeffient la: [-3.80089058e+00 -3.11565508e-02 -9.37009081e-04]
# Do chinh xac cua mo hinh:     R&D Spend     R&D Spend     R&D Spend
# 0   165349.20  2.734036e+10  4.520706e+15
# 1   162597.70  2.643801e+10  4.298760e+15
# 2   153441.51  2.354430e+10  3.612672e+15
# 3   144372.41  2.084339e+10  3.009211e+15
# 4   142107.34  2.019450e+10  2.869786e+15
# 5   131876.90  1.739152e+10  2.293539e+15
# 6   134615.46  1.812132e+10  2.439410e+15
# 7   130298.13  1.697760e+10  2.212150e+15
# 8   120542.52  1.453050e+10  1.751543e+15
# 9   123334.88  1.521149e+10  1.876108e+15
# 10  101913.08  1.038628e+10  1.058497e+15
# 11  100671.96  1.013484e+10  1.020295e+15
# 12   93863.75  8.810404e+09  8.269775e+14
# 13   91992.39  8.462600e+09  7.784948e+14
# 14  119943.24  1.438638e+10  1.725549e+15
# 15  114523.61  1.311566e+10  1.502052e+15
# 16   78013.11  6.086045e+09  4.747913e+14
# 17   94657.16  8.959978e+09  8.481261e+14
# 18   91749.16  8.417908e+09  7.723360e+14
# 19   86419.70  7.468365e+09  6.454138e+14
# 20   76253.86  5.814651e+09  4.433896e+14
# 21   78389.47  6.144909e+09  4.816962e+14
# 22   73994.56  5.475195e+09  4.051346e+14
# 23   67532.53  4.560643e+09  3.079917e+14
# 24   77044.01  5.935779e+09  4.573163e+14
# 25   64664.71  4.181525e+09  2.703971e+14
# 26   75328.87  5.674439e+09  4.274491e+14
# 27   72107.60  5.199506e+09  3.749239e+14
# 28   66051.52  4.362803e+09  2.881698e+14
# 29   65605.48  4.304079e+09  2.823712e+14
# 30   61994.48  3.843316e+09  2.382643e+14
# 31   61136.38  3.737657e+09  2.285068e+14
# 32   63408.86  4.020684e+09  2.549470e+14
# 33   55493.95  3.079578e+09  1.708980e+14
# 34   46426.07  2.155380e+09  1.000658e+14
# 35   46014.02  2.117290e+09  9.742503e+13
# 36   28663.76  8.216111e+08  2.355046e+13
# 37   44069.95  1.942160e+09  8.559092e+13
# 38   20229.59  4.092363e+08  8.278683e+12
# 39   38558.51  1.486759e+09  5.732720e+13
# 40   28754.33  8.268115e+08  2.377441e+13
# 41   27892.92  7.780150e+08  2.170111e+13
# 42   23640.93  5.588936e+08  1.321276e+13
# 43   15505.73  2.404277e+08  3.728006e+12
# 44   22177.74  4.918522e+08  1.090817e+13
# 45    1000.23  1.000460e+06  1.000690e+09
# 46    1315.46  1.730435e+06  2.276318e+09
# 47       0.00  0.000000e+00  0.000000e+00
# 48     542.05  2.938182e+05  1.592642e+08
# 49       0.00  0.000000e+00  0.000000e+00 mpg

# %%
import pandas as pd 
url = '50_Startups.csv'
data = pd.read_csv(url)
data.head()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation = data.corr()
print(correlation)
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
sns.pairplot(data)

# %%
sns.heatmap(correlation,annot = True)
# Out:
# <Axes: >

# %%
data.plot(kind='scatter',x='R&D Spend',y='Profit',figsize=(9,9), color='black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='R&D Spend', ylabel='Profit'>

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()
model.fit(X = pd.DataFrame(data['R&D Spend']),y=data['Profit'])
print('Gia tri Intercept la:',model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
# Out:
# Gia tri Intercept la: 49032.89914125215
# Gia tri Coeffient la: [0.85429137]

# %%
model.score(X = pd.DataFrame(data['R&D Spend']),y=data['Profit'])
# Out:
# 0.9465353160804393

# %%
data.plot(kind='scatter',x='R&D Spend',y='Profit',figsize=(9,9), color='black')
y_pred=model.predict(X = pd.DataFrame(data['R&D Spend']))
plt.plot(data['R&D Spend'],y_pred, color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2]).T
model.fit(X,y=data['Profit'])
print('He so Intercept la:', model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print('Do chinh xac cua mo hinh:', model.score(X,y=data['Profit']))
# Out:
# He so Intercept la: 48128.14916956878
# Gia tri Coeffient la: [ 8.90147291e-01 -2.31821806e-07]
# Do chinh xac cua mo hinh: 0.946703652909133

# %%
import numpy as np
range = np.arange(10000,200000,1000)
X_range = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter',x='R&D Spend',y='Profit',figsize=(9,9),color='black', xlim=(0.7))
plt.plot(range,y_pred,color='red')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3]).T
model.fit(X,y=data['Profit'])
print('He so Intercept la:', model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print('Do chinh xac cua mo hinh:', model.score(X,y=data['Profit']))
# Out:
# He so Intercept la: 43108.76756818297
# Gia tri Coeffient la: [ 1.40072682e+00 -8.82403324e-06  3.64774030e-11]
# Do chinh xac cua mo hinh: 0.9540709421464032

# %%
import numpy as np
range = np.arange(10000,200000,1000)
X_range = pd.DataFrame([range,range**2,range**3]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter',x='R&D Spend',y='Profit',figsize=(9,9),color='black', xlim=(0.7))
plt.plot(range,y_pred,color='red')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3,data['R&D Spend']**2,data['R&D Spend']**3,data['R&D Spend']**2,data['R&D Spend']**3]).T
model.fit(X,y=data['Profit'])
print('He so Intercept la:', model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print('Do chinh xac cua mo hinh:', model.score(X,y=data['Profit']))
