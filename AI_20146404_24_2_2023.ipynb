# %% [markdown]
# <a href="https://colab.research.google.com/github/TruongTrungQuan20146404/AI_17_2_2023/blob/main/AI_20146404_24_2_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 21.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=ca2c95656e3bd80652c5863e704516e6768fa89edab997b03cfc6bb04e725193
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

# %%
x=np.arange(30,71,1)
slow = fuzz.trimf(x,[30,30,40])
medium = fuzz.trimf(x,[30,50,60])
medium_fast = fuzz.trimf(x,[50,65,70])
full_speed = fuzz.trimf(x,[60,70,70])

# %%
plt.figure()
plt.plot(x,slow,'r',linewidth=1.5,label='SLOW')
plt.plot(x,medium,'b',linewidth = 1.5, label = 'medium' )
plt.plot(x,medium_fast,'g',linewidth = 1.5, label = 'medium_fast' )
plt.plot(x,full_speed,'y',linewidth = 1.5, label = 'full_speed' )

# %%
x=np.arange(30,71,1)
slow = fuzz.trapmf(x,[30,30,40,45])
medium = fuzz.trapmf(x,[30,50,60,75])
medium_fast = fuzz.trapmf(x,[50,65,68,70])
full_speed = fuzz.trapmf(x,[60,65,70,75])
plt.figure()
plt.plot(x,slow,'r',linewidth=1.5,label='SLOW')
plt.plot(x,medium,'b',linewidth = 1.5, label = 'medium' )
plt.plot(x,medium_fast,'g',linewidth = 1.5, label = 'medium_fast' )
plt.plot(x,full_speed,'y',linewidth = 1.5, label = 'full_speed' )

# %%
x = np.arange(30,71,1)
slow3 = fuzz.gaussmf(x,30,5)
medium3 = fuzz.gaussmf(x,50,5)
medium_fast3 = fuzz.gaussmf(x,65,5)
full_speed3 = fuzz.gaussmf(x,70,5)
plt.figure()
plt.plot(x,slow3,'r',linewidth = 1.5, label = 'SLOW' )
plt.plot(x,medium3,'b',linewidth = 1.5, label = 'medium' )
plt.plot(x,medium_fast3,'g',linewidth = 1.5, label = 'medium_fast' )
plt.plot(x,full_speed3,'y',linewidth = 1.5, label = 'full_speed' )

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl
food = ctrl.Antecedent(np.arange(0,11,1),'food')
service = ctrl.Antecedent(np.arange(0,11,1),'service')
tip  = ctrl.Consequent(np.arange(10,31,10),'tip')

food ['poor'] = fuzz.trimf(food.universe,[0,0,5])
food ['average'] = fuzz.trimf(food.universe,[0,5,10])
food ['good'] = fuzz.trimf(food.universe,[5,10,10])

service ['poor'] = fuzz.trimf(service.universe,[0,0,5])
service ['average'] = fuzz.trimf(service.universe,[0,5,10])
service ['good'] = fuzz.trimf(service.universe,[5,10,10])

tip ['less'] = fuzz.trimf(tip.universe,[10,10,20])
tip ['normal']= fuzz.trimf(tip.universe,[10,20,30])
tip['good']= fuzz.trimf(tip.universe,[20,30,30])
food.view()
service.view()
tip.view()
service['average'].view()

# %%
rule1 = ctrl.Rule(food['poor']&service['poor'],tip['less'])
rule2 = ctrl.Rule(food['average']&service['poor'],tip['less'])
rule3 = ctrl.Rule(food['good']&service['poor'],tip['normal'])
rule4 = ctrl.Rule(food['poor']&service['average'],tip['less'])
rule5 = ctrl.Rule(food['average']&service['average'],tip['normal'])
rule6 = ctrl.Rule(food['good']&service['average'],tip['good'])
rule7 = ctrl.Rule(food['poor']&service['good'],tip['normal'])
rule8 = ctrl.Rule(food['average']&service['good'],tip['good'])
rule9 = ctrl.Rule(food['good']&service['good'],tip['good'])

# %%
tipping_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9])
tipping = ctrl.ControlSystemSimulation(tipping_ctrl)
tipping.input['food']=5
tipping.input['service']=8
tipping.compute()
print(tipping.output['tip'])
tip.view(sim=tipping)
# Out:
# 21.82945736434109

# %%
x=np.arange(30,71,1)
slow = fuzz.trimf(x,[30,30,40])
medium = fuzz.trimf(x,[30,50,60])
medium_fast = fuzz.trimf(x,[50,65,70])
full_speed = fuzz.trimf(x,[60,70,70])

# %%
#Noi com dien thong minh



import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl



time = ctrl.Antecedent(np.arange(10,181,1),'time')
rice = ctrl.Antecedent(np.arange(100,1001,1),'rice')
power  = ctrl.Consequent(np.arange(0,101,10),'power')

time ['VF'] = fuzz.trimf(time.universe,[10,10,20])
time ['F'] = fuzz.trimf(time.universe,[15,25,40])
time ['N'] = fuzz.trimf(time.universe,[30,60,90])
time ['S'] = fuzz.trimf(time.universe,[50,90,140])
time ['VS'] = fuzz.trimf(time.universe,[120,180,180])

rice ['rat_it'] = fuzz.trimf(rice.universe,[100,120,200])
rice ['it'] = fuzz.trimf(rice.universe,[160,200,500])
rice ['tb'] = fuzz.trimf(rice.universe,[300,350,650])
rice ['nhieu'] = fuzz.trimf(rice.universe,[400,600,700])
rice ['rat_nhieu'] = fuzz.trimf(rice.universe,[700,900,1000])

power ['small'] = fuzz.trimf(power.universe,[10,10,30])
power ['average'] = fuzz.trimf(power.universe,[30,50,80])
power ['high']= fuzz.trimf(power.universe,[70,80,100])


rule1 = ctrl.Rule(time ['VF']&rice['rat_it'],power['small'])
rule2 = ctrl.Rule(time ['F']&rice['rat_it'],power['small'])
rule3 = ctrl.Rule(time ['N']&rice['rat_it'],power['small'])
rule4 = ctrl.Rule(time ['S']&rice['rat_it'],power['average'])
rule5 = ctrl.Rule(time ['VS']&rice['rat_it'],power['average'])
rule6 = ctrl.Rule(time ['VF']&rice['it'],power['small'])
rule7 = ctrl.Rule(time ['F']&rice['it'],power['small'])
rule8 = ctrl.Rule(time ['N']&rice['it'],power['average'])
rule9 = ctrl.Rule(time ['S']&rice['it'],power['average'])
rule10 = ctrl.Rule(time ['VS']&rice['it'],power['high'])
rule11 = ctrl.Rule(time ['VF']&rice['tb'],power['small'])
rule12 = ctrl.Rule(time ['F']&rice['tb'],power['small'])
rule13 = ctrl.Rule(time ['N']&rice['tb'],power['high'])
rule14 = ctrl.Rule(time ['S']&rice['tb'],power['high'])
rule15 = ctrl.Rule(time ['VS']&rice['tb'],power['high'])
rule16 = ctrl.Rule(time ['VF']&rice['nhieu'],power['average'])
rule17 = ctrl.Rule(time ['F']&rice['nhieu'],power['average'])
rule18 = ctrl.Rule(time ['N']&rice['nhieu'],power['average'])
rule19 = ctrl.Rule(time ['S']&rice['nhieu'],power['high'])
rule20 = ctrl.Rule(time ['VS']&rice['nhieu'],power['high'])
rule21 = ctrl.Rule(time ['VF']&rice['rat_nhieu'],power['average'])
rule22 = ctrl.Rule(time ['F']&rice['rat_nhieu'],power['high'])
rule23 = ctrl.Rule(time ['N']&rice['rat_nhieu'],power['high'])
rule24 = ctrl.Rule(time ['S']&rice['rat_nhieu'],power['high'])
rule25 = ctrl.Rule(time ['VS']&rice['rat_nhieu'],power['high'])

powering_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25])
powering = ctrl.ControlSystemSimulation(powering_ctrl)
powering.input['time'] =40
powering.input['rice'] =600
powering.compute()
print(powering.output['power'])
power.view(sim = powering)
# Out:
# 61.18547681539807
