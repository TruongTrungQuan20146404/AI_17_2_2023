# %% [markdown]
# <a href="https://colab.research.google.com/github/TruongTrungQuan20146404/Truong_Trung_Quan_20146404/blob/main/AI_31_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import cifar10
import matplotlib.pyplot as plt

(train_images, train_labels),(test_images,test_labels)= cifar10.load_data()


X=test_images
Y=test_labels

digit = train_images[10]
plt.imshow(digit,cmap=plt.cm.binary)
plt.show()
print('so may la:',train_labels[10])
# Out:
# so may la: [4]

# %%
for i in range (25):
    plt.subplot(5,5,i+1)
    plt.tight_layout()
    plt.imshow(train_images[i],cmap='gray',interpolation='none')
    plt.title('Số:{}'.format(train_labels[i]))
    plt.xticks([])
    plt.yticks([])

# %%
from keras.models import  Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(1000,activation='relu',input_shape=(3072,)))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 1000)              3073000
#
#  dense_7 (Dense)             (None, 10)                10010
#
# ...
# Total params: 3,083,010
# Trainable params: 3,083,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images = train_images.reshape(50000,32*32*3)
train_images = train_images.astype('float32')/255
test_images =  test_images.reshape(10000,32*32*3)
test_images = test_images.astype('float32')/255

# %%
from keras.utils import to_categorical
train_labels = to_categorical(train_labels,10)
test_labels = to_categorical(test_labels,10)

# %%
model.compile(optimizer='rmsprop',loss = 'categorical_crossentropy',metrics = ['accuracy'])

# %%
model.fit(train_images,train_labels,epochs=20,batch_size=128)
test_loss,test_acc=model.evaluate(test_images, test_labels)
print('Mat mat :', test_loss)
print('Do chinh xac :',test_acc)
# Out:
# Epoch 1/20
# 391/391 [==============================] - 21s 52ms/step - loss: 2.3982 - accuracy: 0.2625
# Epoch 2/20
# 391/391 [==============================] - 21s 53ms/step - loss: 1.7953 - accuracy: 0.3590
# Epoch 3/20
# 391/391 [==============================] - 21s 54ms/step - loss: 1.7009 - accuracy: 0.3968
# Epoch 4/20
# 391/391 [==============================] - 20s 51ms/step - loss: 1.6429 - accuracy: 0.4177
# Epoch 5/20
# 391/391 [==============================] - 21s 53ms/step - loss: 1.6000 - accuracy: 0.4348
# Epoch 6/20
# 391/391 [==============================] - 21s 53ms/step - loss: 1.5671 - accuracy: 0.4477
# Epoch 7/20
# 391/391 [==============================] - 20s 51ms/step - loss: 1.5397 - accuracy: 0.4554
# Epoch 8/20
# 391/391 [==============================] - 21s 53ms/step - loss: 1.5145 - accuracy: 0.4636
# Epoch 9/20
# 391/391 [==============================] - 20s 51ms/step - loss: 1.4896 - accuracy: 0.4750
# Epoch 10/20
# ...

# %%
img = plt.imread('truck.jpg')
plt.imshow(img)
plt.show()

# %%
from keras.utils import load_img
from keras.utils.image_utils import img_to_array
import numpy as np

# %%
img = load_img('truck.jpg',target_size=(32,32))

# %%
#model.save('test1.h5')
#model10 = load_model('test1.h5')

plt.imshow(img)
img= img_to_array(img)
img = img.reshape(1,32*32*3)
img = img.astype('float32')
img= img/255
np.argmax(model.predict(img),axis = -1)
# Out:
# 1/1 [==============================] - 0s 55ms/step
# array([4])
